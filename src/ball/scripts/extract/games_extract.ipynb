# %% [markdown]
# Testing different endpoints, to see which is the best to store game_data for

# %%
from nba_api.stats.endpoints import (scoreboardv2,
                                     boxscoretraditionalv2,
                                     leaguegamelog)
import pandas as pd

# %%
scoreboard = scoreboardv2.ScoreboardV2().get_data_frames()[0]
scoreboard.head(3)
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE  ... WH_STATUS  WNBA_COMMISSIONER_FLAG
# 0  2026-01-08T00:00:00              1  ...         1                       0
# 1  2026-01-08T00:00:00              2  ...         0                       0
# 2  2026-01-08T00:00:00              3  ...         1                       0
#
# [3 rows x 18 columns]

# %%
boxscore = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id='0022100001').get_data_frames()[1]
boxscore.head()
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION  ...  TO  PF  PTS  PLUS_MINUS
# 0  0022100001  1610612749     Bucks               MIL  ...   7  19  127          23
# 1  0022100001  1610612751      Nets               BKN  ...  12  17  104         -23
#
# [2 rows x 25 columns]

# %%
games = leaguegamelog.LeagueGameLog(league_id='00', 
                                    season='2015-16', 
                                    season_type_all_star='Regular Season'
                                ).get_data_frames()[0]

games.iloc[:, :7].sort_values(by="GAME_ID", ascending=True).head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION  ...     GAME_ID   GAME_DATE      MATCHUP
# 4     22015  1610612765               DET  ...  0021500001  2015-10-27    DET @ ATL
# 5     22015  1610612737               ATL  ...  0021500001  2015-10-27  ATL vs. DET
# 0     22015  1610612739               CLE  ...  0021500002  2015-10-27    CLE @ CHI
# 2     22015  1610612741               CHI  ...  0021500002  2015-10-27  CHI vs. CLE
# 1     22015  1610612740               NOP  ...  0021500003  2015-10-27    NOP @ GSW
#
# [5 rows x 7 columns]

# %% [markdown]
# leaguegamelog is promising - update to db

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import (create_engine, text)

# %%
load_dotenv()

engine = create_engine(
    f"postgresql+psycopg2://"
    f"{os.environ['USER']}:{os.environ['PASSWORD']}"
    f"@{os.environ['HOST']}:{os.environ['PORT']}"
    f"/{os.environ['DB']}",
    pool_pre_ping=True
)

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM players;"))
    
    result = pd.DataFrame(result).head()

    conn.close()
    
result
# Out:
#    player_id       full_name first_name last_name is_active   birthdate
# 0          2     Byron Scott      Byron     Scott     False  1961-03-28
# 1          3      Grant Long      Grant      Long     False  1966-03-12
# 2          7     Dan Schayes        Dan   Schayes     False  1959-05-10
# 3          9  Sedale Threatt     Sedale   Threatt     False  1961-09-10
# 4         12      Chris King      Chris      King     False  1969-07-24
